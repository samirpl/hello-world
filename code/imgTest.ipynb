# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

f = mpimg.imread('../pictures/Samir.jpg')
print (f.shape)
print (f.dtype)
print (f.max(),f.min())
# Out:
# (1139, 1205, 3)
# uint8
# 255 0

# %%
plt.imshow(f[::10,::10])
plt.colorbar()

# %%
plt.imshow(f)
plt.colorbar()
